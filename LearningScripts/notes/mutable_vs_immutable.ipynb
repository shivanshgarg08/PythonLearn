# %%
a = [10]
b = a 
a[0] = 20
print(b)
# Out:
# [20]

# %% [markdown]
# Mutability Vs Immutability

# %% [markdown]
# a = [10]
# b = a
# a[0] = 20
# print(b)
#
# here, a variable name binds with object 10, but i can see square brackets so this 10 is of class list, in second libne i see b = a so b variable name binds with varaiable name a object 10, now in line 3 a has new object 0 which rebinds with new object 20, so our answer will 10

# %% [markdown]
# Assignment to a variable name
#
# a = 20
#
# ↓
#
# Rebinds the name.
#
#
# Assignment to an element
#
# a[0] = 20
#
# ↓
#
# Modifies the existing object.

# %%
number = [1,2,3]
other = number
number = [10,20,30]
print(other)
#here output will be [10,20,30] as variable name number binds with the object of list [1,2,3] and variable name other binds with the object of variable name number which is binder with the object 1,2,3 since  print(other is here) the answer will be [1,2,3]
# Out:
# [1, 2, 3]

# %%
a = 5
b = a
a = 6
print(b)
# Out:
# 5

# %%
a = [10]
b = a 
a[0] = 20 # Here indexing happend as changed the value of a at index [0] and new object value asssigned which is 20 so it also changed it in b
print(b)
# Out:
# [20]

# %%
#Lesson 0.3 Part C
#Identity(is ) Vs Equality(==)

a = [1, 2]

b = [1 , 2]
a = b
print(id(a))

print(a == b)
print(a is b )
print(type(a))

#@
# Out:
# 1810835356160
# True
# False
# <class 'list'>

# %%
a = [ 1, 2]
b = 3
a = b
print(a == b)
# Out:
# True

# %%
a = [1,3] # a --- object [1,2] A
b =[1,2]  #B -- object [1,2] B two obejcts created
a=b
''' Variable name  a stores reference point towards object [1,3] then b variable name binds with object [1,2] now a rebinded with the value of variable name b'''
print(a)
print(b)
print(id(a))
print(id(b))
# Out:
# [1, 2]
# [1, 2]
# 1805003663872
# 1805003663872

# %%
a = [1 , 2]
b = a #Here variable B binds with object of a

# %%
a = [1]
b = [1]
print(a==b) # prediction- True
print(a is b) # prediction- False
# Out:
# True
# False

# %%
a = [1]
b = a
print(a == b) #True
print(a is b) #True
# Out:
# True
# True

# %%
a = [1]
b = a
b.append(2)
print(a == b) # False
print( a is b) # False
# Out:
# True
# True

# %%
a = [1]
b = a
b = [2]
print(a == b) #False
print(a  is b)#False
# Out:
# False
# False

# %%
a  = [1]
b = [1]
print(a == b)
print(a is b)
# Out:
# True
# False
