# %% [markdown]
# #Introduction To python--
# Numbers  --
# Here the interpreter acts as a calculator  performing = ,- ,*,/ operations

# %%
2 + 2
10 - 10* 6 
(10 - 6) * 2
# Out:
# 8

# %%
17 / 3  # classic division returns a float


17 // 3  # floor division discards the fractional part

17 % 3  # the % operator returns the remainder of the division

5 * 3 + 2  # floored quotient * divisor + remainder
# Out:
# 17

# %%
17// 3
# Out:
# 5

# %%
15 % 3
# Out:
# 0

# %%
15 / 2
# Out:
# 7.5

# %%
15/3
# Out:
# 5.0

# %%
5 ** 2  # 5 squared

2 ** 7  # 2 to the power of 7
# Out:
# 128

# %%
width = 20
height = 5 * 9
width * height
# Out:
# 900

# %%
print("doesn't")
print("doesn\'t")
# Out:
# doesn't
# doesn't

# %%
s = 'print firstline.\n  second line'
print(s)
# Out:
# print firstline.
#   second line

# %%
# 3 times 'un', followed by 'ium'
3 * 'un' + 'ium'
# Out:
# 'unununium'

# %%
prefix = "py"
print(prefix + 'thon') #Using concatenation
# Out:
# python

# %%
'''Strings can be indexed (subscripted), with the first character having index 0. There is no separate character type; a character is simply a string of size one'''
# Out:
# 'Strings can be indexed (subscripted), with the first character having index 0. There is no separate character type; a character is simply a string of size one'

# %%
word = 'python'
word[0]
word[0:]
word[:3]
word[-1:]
word[-1:-42]
word[0:42]
word[-6]
word[-6:71]
word[-6:]
word[1:-6]
word[2: -6]
word[6: -6]
# Out:
# ''

# %%
score = 100
player_score = score
score = 200
print(player_score)
type(print(player_score))
# Out:
# 100
# 100
# NoneType

# %%
word = "Python"
print(word[1])
print(word[-2])
print(word[2:5])
word[20]
# Out:
# y
# o
# tho
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[14], line 5
#       1 word = "Python"
#       2 print(word[1])
#       3 print(word[-2])
#       4 print(word[2:5])
# ----> 5 word[20]
#
# IndexError: string index out of range

# %%
word= 'python'
word[20:]
# Out:
# ''

# %%
word = 'python'
print(word[:-4])
print(word[::2])
print(word[::-1])
# Out:
# py
# pto
# nohtyp
