# %%
print("Line 1")
print("Line 2 ")
print("Line 3")
# Out:
# Line 1
# Line 2
# Line 3

# %%
print("Start")
x = 100 
print("Value:", x)
print("End")
# Out:
# Start
# Value: 100
# End

# %%
print("Before Error")
#print(10/0)
print("After error")
# Out:
# Before Error
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# Cell In[3], line 2
#       1 print("Before Error")
# ----> 2 print(10/0)
#       3 print("After error")
#
# ZeroDivisionError: division by zero

# %% [markdown]
# My observation here is when python interpreter start executing code line by line at execution of line it found an error called zero division error as 10/0 is not defined mathematically, and also observed here terminal prompts error not line 1 and line 2 in which the code is correct

# %% [markdown]
# Computer Can't execute Python code directly as computer understand machine level klabuage like binary numbers, so python interpreter needs to comnvert high level human understandable code intp machine readable code by translating it into binary numbers intructions so that machine can understand and execute it.
#
# The role of python Interpreter is to Execute line by line python code, by transalating high level human understandable python code into low level, binary digit machine understandable code.t also
#
# checks syntax
# executes instructions
# manages objects
# reports errors.
#
# "After error" Does't gets printed as python interpreter execttues code line by line and it found an error at line 2 of the code, so if python code has an error terminal will prompt error
#
# If line 27 raise an unhandled error , in suppose 100 lines of program, rest 28-100 lines of code will be not executed

# %% [markdown]
# Ans-1 Source Code is the code we write in the python file ex .py or ipynb files in which code is writter
#
# Ans-2 ByteCode is a file creatred by python compiler translating source code into bytecode and is used by pythonvirtual machine later on for machine intructions and execution
# (Have a doubt here Bytecode is the code in which compilation and interpretetions happens by cpython compiler, and errors like zerodivion or syntac or unhandled error found in the byte code, pvm takes as a error and in terminal machine prompts error, my main doubt here is what happens in byte code, in error handling or it handled further)
#
# ans- 3 Python doesnt execute code directly as it is designed to interpret code line by line give runtime errors, unlike c here code is more simple and easy but difficult for machine to understand so a structure is created to make that simple code inm machine understandable code we learned above
#
# ans -5 python is slower than c as c  directly converts source code into machine understandbbale code whereas python converts it into byte code, interpretation and compilation happends then pvm runs the byte code then in os cpu insstrructionsp performed
