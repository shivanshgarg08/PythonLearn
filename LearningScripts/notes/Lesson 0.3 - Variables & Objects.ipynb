# %% [markdown]
# what is a variable?
# A variable is a name or reference that points towards objects, it acts as a reference point. Machine uses this reference point as a dictionary for memory allocation
#
# what is an object?
# An object is an entity in python since python is based on oops every element is python is an object contained in class
#
# what does = actually do?
# suppose we have a = 10 here it means a is an varibale points reffering to the object 10 memory allocation, here using = we can say =  is used for connecting the refernce name to the object
# ans -3 when python executes a=b  the variable name a is pointed towards the object of b where varibale name b is pointing towards suppose a = 10, a= b so a points towards 10 and b points towards 10 using a=b,
#
# ans-4 why didnt chaninging score change player_score
# since player score points towards the previous enetity of 100 so it points towards memory allocation of object 100, so it doesnt depend on score name variable, theen the value of player_score will remain same , wherwas new memory will be allocated 200 obhect point memory alkoication

# %% [markdown]
# a = 10
# b = a
# c = b
#
# a = 20
#
# here,
# a - 10
# b - 10 (as b -a - 10object)
# c- 10 (as c-b-a-10object)
#
# after
#
# a - 20 (a=20, so variable name points to object 20)
# b - 10
# c -10

# %%
print("Hello world")
# Out:
# Hello world

# %%
#Experimentation and Breaking the code work today
a =  5
b = a
print(a) #a variable name binds with object 5 
print(b) #b variable name binds with object of vairable name a
# Out:
# 5
# 5

# %%
a= 5
b = a

a = 7

print(a) # 7
print(b) # 5
# Out:
# 7
# 5

# %%
x = 100
y = x
z = y

x = 300

print(x)
print(y)
print(z)
# Out:
# 300
# 100
# 100

# %%
#Breaking the code 
x = 10 
y = x

x = x + 1 
print(x) # 11
print(y) # 10
# Out:
# 11
# 10

# %%
number = 100
copy = number 
number = number + 20
print(copy) # 100
# Out:
# 100

# %%
a = 1
b = a
c = b
d = c
e = d
a = 999
print(a) #999
print(b)#1
print(c)
print(d)
print(e)
# Out:
# 999
# 1
# 1
# 1
# 1
